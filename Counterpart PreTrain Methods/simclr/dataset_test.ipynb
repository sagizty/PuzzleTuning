# %%
from data_aug.contrastive_learning_dataset import ContrastiveLearningDataset
import torch


dataset = ContrastiveLearningDataset('/data/ImageFolderLike/pRCC_CLS')

train_dataset = dataset.get_dataset('local', n_views=2, mode='train', img_size=224)

train_loader = torch.utils.data.DataLoader(
    train_dataset, batch_size=1, shuffle=True, pin_memory=True, drop_last=True)
# Out:
# dataset: local

# %%
img_list = []
for images, _ in train_loader:
    img_list = images
    break

# %%
import torch
import torchvision.transforms as transforms
from PIL import Image
import matplotlib.pyplot as plt

# print(img_list[0].squeeze().shape)
plt.imshow(img_list[0].squeeze().permute(1, 2, 0))

# %%
plt.imshow(img_list[1].squeeze().permute(1, 2, 0))

# %%
img_list = []
skip_cnt = 3
for images, _ in train_loader:
    img_list = images
    skip_cnt -= 1
    if skip_cnt == 0:
        break

# %%
plt.imshow(img_list[0].squeeze().permute(1, 2, 0))

# %%
plt.imshow(img_list[1].squeeze().permute(1, 2, 0))

# %%
from data_aug.contrastive_learning_dataset import ContrastiveLearningDataset
import torch


dataset = ContrastiveLearningDataset('./datasets')

train_dataset = dataset.get_dataset('stl10', n_views=2, mode='train', img_size=224)

train_loader = torch.utils.data.DataLoader(
    train_dataset, batch_size=1, shuffle=True, pin_memory=True, drop_last=True)
# Out:
# dataset: stl10
# Files already downloaded and verified

# %%
img_list = []
skip_cnt = 123
for images, _ in train_loader:
    img_list = images
    skip_cnt -= 1
    if skip_cnt == 0:
        break

# %%
plt.imshow(img_list[0].squeeze().permute(1, 2, 0))

# %%
plt.imshow(img_list[1].squeeze().permute(1, 2, 0))
